# %%
import os
from os import walk
import torch
from torchvision import transforms

# %%
print(os.listdir(''))
# Out:
# ['.ipynb_checkpoints', 'archive.zip', 'Assessment3_MachineLearningProjectTemplate (working file).ipynb', 'Assessment3_MachineLearningProjectTemplate.ipynb', 'training_data', 'Untitled.ipynb']

# %%
transform=transforms.Compose([
        transforms.ToTensor()
        ])
