# %% [markdown]
# # Assessment 2
# ## Question 10
#
# The following code creates a simple Bayesian Network
#
# Use Maximum Likelihood Estimation to estimate the Conditional Probability Tables for the network and calculate the probability P(C|B=1) using variable elimination.

# %%
#This code is modified from the examples at pgmpy.org Copyright (c) 2013-2021 pgmpy
#Importing Library
import pandas as pd
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator
from pgmpy.inference import VariableElimination

data = pd.DataFrame(data={'A': [0, 0, 1], 'B': [0, 1, 0], 'C': [1, 1, 0]})
model = BayesianModel([('A', 'C'), ('B', 'C')])
