# %% [markdown]
# # Exercise 4.1: Learning model parameters
# In this exercise we will explore how we can learn the parameters of a given network from data using different methods provided by **pgmpy**
#
# - MaximumLikelihood Estimator (pgmpy.estimators.MaximumLikelihoodEstimator)
# - Bayesian Estimator (pgmpy.estimators.BayesianEstimator)
# - Expectation Maximization (pgmpy.estimators.ExpectationMaximization)
#
# In the examples, we will try to generate some data from given models and then try to learn the model parameters back from the generated data.

# %% [markdown]
# Some medical researchers have created a Bayesian network that models the inter-relationship between (some) diseases and observed symptoms. Our job is to learn parameters for the network based on health records. Unfortunately, as it happens in the real world, certain records have missing values. We need to do our best to compute the parameters for the network, so that it can be used for diagnosis later on.
#
# We use a medical diagnosis system built from 10,000 broken (1 attribute missing) patient records alarm.bif
#
# There are eight possible diagnoses: hypovolemia, left ventricular failure, Anaphylaxis, insufficient analgesia, pulmonary embolus, intubation, kinked tube, and disconnection. The observable nodes are CVP, PCWP, History, TPR, Blood Pressure, CO, HR BP, HR EKG, HR SAT, SaO2, PAP, MV, Min Vol, Exp CO2, FiO2 and Pres.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## First we generate some data

# %%
#This code is modified from the examples at pgmpy.org Copyright (c) 2013-2021 pgmpy
# Use the alarm model to generate data from it.
import numpy as np
from pgmpy.utils import get_example_model
from pgmpy.sampling import BayesianModelSampling

alarm_model = get_example_model('alarm')
samples = BayesianModelSampling(alarm_model).forward_sample(size=int(1e5))
samples.head()
# Out:
# Generating for node: HISTORY:  24%|████▍             | 9/37 [00:00<00:02, 10.44it/s]/opt/miniconda3/lib/python3.8/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:521: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   warn(
# Generating for node: BP: 100%|██████████████████████| 37/37 [00:02<00:00, 13.52it/s]
#   HISTORY     CVP    PCWP HYPOVOLEMIA LVEDVOLUME LVFAILURE STROKEVOLUME  \
# 0   FALSE  NORMAL  NORMAL       FALSE     NORMAL     FALSE       NORMAL
# 1   FALSE  NORMAL  NORMAL       FALSE     NORMAL     FALSE       NORMAL
# 2   FALSE  NORMAL  NORMAL       FALSE     NORMAL     FALSE       NORMAL
# 3   FALSE  NORMAL  NORMAL       FALSE     NORMAL     FALSE       NORMAL
# 4   FALSE  NORMAL  NORMAL       FALSE     NORMAL     FALSE       NORMAL
#
#   ERRLOWOUTPUT  HRBP HREKG  ... MINVOLSET VENTMACH VENTTUBE VENTLUNG VENTALV  \
# 0        FALSE   LOW   LOW  ...    NORMAL   NORMAL      LOW     ZERO    ZERO
# ...

# %% [markdown]
# ## Next we define a model structure
#
# In this case, since we are trying to learn the model parameters back, we will use the model structure that we used to generate the data from.

# %%
# Defining the Bayesian Model structure

from pgmpy.models import BayesianModel

model_struct = BayesianModel(ebunch=alarm_model.edges())
model_struct.nodes()
# Out:
# NodeView(('HYPOVOLEMIA', 'LVEDVOLUME', 'STROKEVOLUME', 'CVP', 'PCWP', 'LVFAILURE', 'HISTORY', 'CO', 'ERRLOWOUTPUT', 'HRBP', 'ERRCAUTER', 'HREKG', 'HRSAT', 'INSUFFANESTH', 'CATECHOL', 'ANAPHYLAXIS', 'TPR', 'BP', 'KINKEDTUBE', 'PRESS', 'VENTLUNG', 'FIO2', 'PVSAT', 'SAO2', 'PULMEMBOLUS', 'PAP', 'SHUNT', 'INTUBATION', 'MINVOL', 'VENTALV', 'DISCONNECT', 'VENTTUBE', 'MINVOLSET', 'VENTMACH', 'EXPCO2', 'ARTCO2', 'HR'))

# %% [markdown]
# ## Then we can learn the CPTs from the data we have generated.

# %% [markdown]
# ### Fitting the model using Maximum Likelihood Estimator
#
# Here we use the Maximum Likelihood Estimator to estimate the CPDs. In this example we first show how to estimate the CPDs for single nodes and display these.

# %%
# Fitting the model using Maximum Likelihood Estimator

from pgmpy.estimators import MaximumLikelihoodEstimator

mle = MaximumLikelihoodEstimator(model=model_struct, data=samples)

# Estimating the CPD for a single node.
print(mle.estimate_cpd(node='FIO2'))
print(mle.estimate_cpd(node='CVP'))
# Out:
# +--------------+---------+
# | FIO2(LOW)    | 0.05012 |
# +--------------+---------+
# | FIO2(NORMAL) | 0.94988 |
# +--------------+---------+
# +-------------+----------------------+----------------------+----------------------+
# | LVEDVOLUME  | LVEDVOLUME(HIGH)     | LVEDVOLUME(LOW)      | LVEDVOLUME(NORMAL)   |
# +-------------+----------------------+----------------------+----------------------+
# | CVP(HIGH)   | 0.6955032326546366   | 0.011295606009262396 | 0.010494028769827182 |
# +-------------+----------------------+----------------------+----------------------+
# | CVP(LOW)    | 0.009939206793399595 | 0.9474754320569299   | 0.04071228752786811  |
# +-------------+----------------------+----------------------+----------------------+
# | CVP(NORMAL) | 0.2945575605519637   | 0.04122896193380775  | 0.9487936837023047   |
# +-------------+----------------------+----------------------+----------------------+

# %% [markdown]
# You can also estimate all the CPDs at once using:

# %%
# Estimating CPDs for all the nodes in the model
mle.get_parameters()[:10] # Show just the first 10 CPDs in the output
# Out:
# [<TabularCPD representing P(HYPOVOLEMIA:2) at 0x140170a00>,
#  <TabularCPD representing P(LVEDVOLUME:3 | HYPOVOLEMIA:2, LVFAILURE:2) at 0x1401703a0>,
#  <TabularCPD representing P(STROKEVOLUME:3 | HYPOVOLEMIA:2, LVFAILURE:2) at 0x140170640>,
#  <TabularCPD representing P(CVP:3 | LVEDVOLUME:3) at 0x140170af0>,
#  <TabularCPD representing P(PCWP:3 | LVEDVOLUME:3) at 0x140189130>,
#  <TabularCPD representing P(LVFAILURE:2) at 0x1401904c0>,
#  <TabularCPD representing P(HISTORY:2 | LVFAILURE:2) at 0x140190130>,
#  <TabularCPD representing P(CO:3 | HR:3, STROKEVOLUME:3) at 0x1401704c0>,
#  <TabularCPD representing P(ERRLOWOUTPUT:2) at 0x1401899a0>,
#  <TabularCPD representing P(HRBP:3 | ERRLOWOUTPUT:2, HR:3) at 0x1400f24c0>]

# %% [markdown]
# To verify that the estimates are close to CPDs in the known Bayesian network we use:

# %%
# Verifying that the learned parameters are almost equal.
np.allclose(alarm_model.get_cpds('FIO2').values, mle.estimate_cpd('FIO2').values, atol=0.01)
# Out:
# True

# %% [markdown]
# ### Fitting the model using Bayesian Estimator
# The following shows how we can use the Bayesian Estimator to estimate the CPDs.

# %%
# Fitting using Bayesian Estimator
from pgmpy.estimators import BayesianEstimator

best = BayesianEstimator(model=model_struct, data=samples)

print(best.estimate_cpd(node='FIO2', prior_type="BDeu", equivalent_sample_size=1000))
# Uniform pseudo count for each state. Can also accept an array of the size of CPD.
print(best.estimate_cpd(node='CVP', prior_type="dirichlet", pseudo_counts=100))

# Learning CPDs for all the nodes in the model. For learning all parameters with BDeU prior, a dict of
# pseudo_counts need to be provided
best.get_parameters(prior_type="BDeu", equivalent_sample_size=1000)[:10]
# Out:
# +--------------+-----------+
# | FIO2(LOW)    | 0.0545743 |
# +--------------+-----------+
# | FIO2(NORMAL) | 0.945426  |
# +--------------+-----------+
# +-------------+----------------------+----------------------+----------------------+
# | LVEDVOLUME  | LVEDVOLUME(HIGH)     | LVEDVOLUME(LOW)      | LVEDVOLUME(NORMAL)   |
# +-------------+----------------------+----------------------+----------------------+
# | CVP(HIGH)   | 0.6903357747550651   | 0.021850759313886157 | 0.011863520029411349 |
# +-------------+----------------------+----------------------+----------------------+
# | CVP(LOW)    | 0.014553410063730619 | 0.9273462252813285   | 0.04195359228517696  |
# +-------------+----------------------+----------------------+----------------------+
# | CVP(NORMAL) | 0.29511081518120424  | 0.050803015404785316 | 0.9461828876854117   |
# +-------------+----------------------+----------------------+----------------------+
# [<TabularCPD representing P(HYPOVOLEMIA:2) at 0x1401860a0>,
# ...

# %% [markdown]
# In either case once you have the estimates you can add these CPDs to your model to perform inference as shown below:

# %%
# Shortcut for learning all the parameters and adding the CPDs to the model.

model_struct = BayesianModel(ebunch=alarm_model.edges())
model_struct.fit(data=samples, estimator=MaximumLikelihoodEstimator)
print(model_struct.get_cpds('FIO2'))

model_struct = BayesianModel(ebunch=alarm_model.edges())
model_struct.fit(data=samples, estimator=BayesianEstimator, prior_type='BDeu', equivalent_sample_size=1000)
print(model_struct.get_cpds('FIO2'))
# Out:
# +--------------+---------+
# | FIO2(LOW)    | 0.04987 |
# +--------------+---------+
# | FIO2(NORMAL) | 0.95013 |
# +--------------+---------+
# +--------------+-----------+
# | FIO2(LOW)    | 0.0543267 |
# +--------------+-----------+
# | FIO2(NORMAL) | 0.945673  |
# +--------------+-----------+

# %% [markdown]
# ### Fitting the model using EM
# The Expecation Maximization (EM) algorithm can also learn the parameters when we have some latent variables in the model.
#
# **Warning this takes a very long time to run**

# %%
from pgmpy.estimators import ExpectationMaximization as EM

# Define a model structure with latent variables
model_latent = BayesianModel(ebunch=alarm_model.edges(), latents=['HYPOVOLEMIA', 'LVEDVOLUME', 'STROKEVOLUME'])

# Dataset for latent model which doesn't have values for the latent variables
samples_latent = samples.drop(model_latent.latents, axis=1)

model_latent.fit(samples_latent, estimator=EM)
# Out:
#   7%|███                                         | 7/100 [27:17<6:02:54, 234.14s/it]
# KeyboardInterrupt
