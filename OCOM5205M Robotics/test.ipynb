# %%
import tester

# %%
import pandas as pd

# %%
import numpy as np

# %%
import rclpy as ros

# %%
import os
os.environ['PYTHONPATH'] = '/mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/'
os.environ['PYTHONPATH']

# %%
import os
os.environ['PYTHONPATH']

# %%
import nbimporter
from Lesson5_MonteCarloMethods import *

# %%
import sys
len(sys.modules)

# %%
import os
import nbimporter
loader = nbimporter.NotebookLoader()
fnames = ['Lesson3_MDPsGridWorld.ipynb']
directory = os.getcwd() + '/'
for file in fnames:
    loader.load_module(file)
from Lesson3_MDPsGridWorld import *
# Out:
# NotbookLoader path: /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson3_MDPsGridWorld.ipynb
# module fullname: Lesson3_MDPsGridWorld
# Importing Jupyter notebook from /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson3_MDPsGridWorld.ipynb

# %%
from Lesson3_MDPsGridWorld import *

# %%
import os
import nbimporter
loader = nbimporter.NotebookLoader()
fnames = ['Lesson3_MDPsGridWorld.ipynb'
         ,'Lesson4_DynamicProgramming.ipynb'
         ,'Lesson5_MonteCarloMethods.ipynb'
         ,'Lesson7_TemporalDifferenceMethods.ipynb'
         ,'Lesson8_nStepsMethods.ipynb'
         ,'Lesson9_PlanningMethods.ipynb'
         ,'Lesson11_IntroductionApproximateMethods.ipynb'
         ,'Lesson12_ApproximatePrediction.ipynb'
         ,'Lesson13_ApproximateControl.ipynb'
         ,'Lesson14_EligibilityTraces_Prediction_Control.ipynb'
         ,'Lesson15_Nonlinear_Approximate_Control.ipynb']
directory = os.getcwd() + '/'
for file in fnames:
    loader.load_module(directory + file)
# Out:
# NotbookLoader path: /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson3_MDPsGridWorld.ipynb
# module fullname: /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson3_MDPsGridWorld
# Importing Jupyter notebook from /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson3_MDPsGridWorld.ipynb
# NotbookLoader path: /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson4_DynamicProgramming.ipynb
# module fullname: /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson4_DynamicProgramming
# Importing Jupyter notebook from /mnt/c/Users/Wes/OneDrive - University of Leeds/OCOM5205M Robotics/Lesson4_DynamicProgramming.ipynb
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      15 directory = os.getcwd() + '/'
#      16 for file in fnames:
# ...

# %%
import nbimporter
d_path = os.getcwd()
loader = nbimporter.NotebookLoader()
notebooks = [f in d_path if f]

# %%
import os
os.environ.get('UNI_FOLDER')

# %%
import sys
sys.meta_path

# %%
import sys
sys.path

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))

# %%
import os
os.getcwd()

# %%
import site; print('\n'.join(site.getsitepackages()))
# Out:
# /home/weschiu/miniconda3/envs/tf/lib/python3.12/site-packages
