# %% [markdown]
# # Correlation and Regression
#
# Given pairs of measurements we may want to determine whether there is any relationship between them. e.g. If we know the ages and heights of a sample of children, we might want to know if older children are generally taller than younger children, or are age and height unrelated?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# data from https://www.kaggle.com/datasets/camnugent/california-housing-prices
df = pd.read_csv('housing.csv')

# %%
df.head()

# %%
df.info()

# %%
#Lets look at our data distribution, using univariate analysis (analysis of 1 variable).
df.hist(bins=60, figsize=(15,9),color='b')
plt.show()

# %% [markdown]
# #### Odd Patterns and Outliers
# - On first impression, a few outlier (inconsistent with entire set) groups are present in our data;  possibly due to the way in which the data was sampled ( 'housing_median_age' & 'median_house_value' ).
# - House_median_age is one possible feature with such outliers. Also having a lot of local peaks (all are quite gradual) but one really odd peak at the maximum value stands out. It has some slight discontinuity in data (which becomes visible with the adjustment of bins)
# - Feature Median_house_value has an odd peak at its maximum value (around 500k), which could be an outlier.
#
# #### Less Noticeable Outliers
#
# - We have quite a few skewed (less centralised) data distributions, 6 features have such distributions, which is quite a lot and slightly concerning.
# - The range of the y axis for some of these features is quite broad (eg. population), indicating we have quite a few outliers, but unlike the first two, we can apply transformation to features and attempt to correct it.
# - Population, total_bedrooms and total_rooms represent somewhat connected things, also have similar distribution which is skewed towards smaller values.

# %% [markdown]
# ## Correlation
#
# The most common measurement of correlation is called Pearson's coefficient. The value ranges from -1 to +1, with 0 indicating that the two measurements are completely unrelated in this sample.
#
# This correlation coefficient considers whether the relationship between the data can be well described using a straight line. If one value increases by a fixed amount then should we expect the other value also to increase by a fixed amount? It is most appropriate to use the correlation coefficient on two variables which are continuous and thought to be normally distributed.

# %%
df.corr()
#df.corr(method='spearman')
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_73a05_row0_col0,#T_73a05_row1_col1,#T_73a05_row2_col2,#T_73a05_row3_col3,#T_73a05_row4_col4,#T_73a05_row5_col5,#T_73a05_row6_col6,#T_73a05_row7_col7,#T_73a05_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_73a05_row0_col1,#T_73a05_row1_col0,#T_73a05_row1_col8,#T_73a05_row2_col3,#T_73a05_row2_col4,#T_73a05_row2_col5,#T_73a05_row2_col6,#T_73a05_row2_col7,#T_73a05_row3_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_73a05_row0_col2{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_73a05_row0_col3{
#             background-color:  #9ebeff;
#             color:  #000000;
#         }#T_73a05_row0_col4{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_73a05_row0_col5{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_73a05_row0_col6,#T_73a05_row1_col2{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_73a05_row0_col7{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_73a05_row0_col8{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_73a05_row1_col3{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_73a05_row1_col4{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_73a05_row1_col5{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_73a05_row1_col6,#T_73a05_row7_col2{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_73a05_row1_col7{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_73a05_row2_col0,#T_73a05_row5_col1{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_73a05_row2_col1{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_73a05_row2_col8{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_73a05_row3_col0{
#             background-color:  #dddcdc;
#             color:  #000000;
#         }#T_73a05_row3_col1{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_73a05_row3_col4,#T_73a05_row4_col3{
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }#T_73a05_row3_col5{
#             background-color:  #d95847;
#             color:  #000000;
#         }#T_73a05_row3_col6{
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }#T_73a05_row3_col7,#T_73a05_row8_col6{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_73a05_row3_col8,#T_73a05_row7_col6{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_73a05_row4_col0{
#             background-color:  #e1dad6;
#             color:  #000000;
#         }#T_73a05_row4_col1{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_73a05_row4_col2{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_73a05_row4_col5{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_73a05_row4_col6,#T_73a05_row6_col4{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_73a05_row4_col7{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_73a05_row4_col8{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_73a05_row5_col0{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_73a05_row5_col2{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_73a05_row5_col3{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_73a05_row5_col4{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_73a05_row5_col6,#T_73a05_row6_col5{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_73a05_row5_col7{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_73a05_row5_col8{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_73a05_row6_col0{
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }#T_73a05_row6_col1{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_73a05_row6_col2{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_73a05_row6_col3{
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }#T_73a05_row6_col7{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_73a05_row6_col8{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_73a05_row7_col0{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_73a05_row7_col1{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_73a05_row7_col3{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_73a05_row7_col4{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_73a05_row7_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_73a05_row7_col8{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_73a05_row8_col0{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_73a05_row8_col1{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_73a05_row8_col2{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_73a05_row8_col3{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_73a05_row8_col4{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_73a05_row8_col5{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_73a05_row8_col7{
#             background-color:  #f6a586;
#             color:  #000000;
#         }</style><table id="T_73a05_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >longitude</th>        <th class="col_heading level0 col1" >latitude</th>        <th class="col_heading level0 col2" >housing_median_age</th>        <th class="col_heading level0 col3" >total_rooms</th>        <th class="col_heading level0 col4" >total_bedrooms</th>        <th class="col_heading level0 col5" >population</th>        <th class="col_heading level0 col6" >households</th>        <th class="col_heading level0 col7" >median_income</th>        <th class="col_heading level0 col8" >median_house_value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73a05_level0_row0" class="row_heading level0 row0" >longitude</th>
#                         <td id="T_73a05_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_73a05_row0_col1" class="data row0 col1" >-0.924664</td>
#                         <td id="T_73a05_row0_col2" class="data row0 col2" >-0.108197</td>
#                         <td id="T_73a05_row0_col3" class="data row0 col3" >0.044568</td>
#                         <td id="T_73a05_row0_col4" class="data row0 col4" >0.069608</td>
#                         <td id="T_73a05_row0_col5" class="data row0 col5" >0.099773</td>
#                         <td id="T_73a05_row0_col6" class="data row0 col6" >0.055310</td>
#                         <td id="T_73a05_row0_col7" class="data row0 col7" >-0.015176</td>
#                         <td id="T_73a05_row0_col8" class="data row0 col8" >-0.045967</td>
#             </tr>
#             <tr>
#                         <th id="T_73a05_level0_row1" class="row_heading level0 row1" >latitude</th>
#                         <td id="T_73a05_row1_col0" class="data row1 col0" >-0.924664</td>
#                         <td id="T_73a05_row1_col1" class="data row1 col1" >1.000000</td>

# %% [markdown]
# Target variable `median_house_value` is very mildly correlated to all but one feature here: median_income, so one might outline this as an important feature.

# %%
sns.heatmap(df.corr(), cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Significance
#
# Is the reported correlation likely to have occurred by chance? Use scipy to check with paired series of data, find the pearson's correlation coefficient and the p-value. The p-value is interpreted as the probability that the observed correlation could have occurred by chance by sampling from non-correlated data.
#
# With very large data sets it is pretty easy to get statistical significance by this method, in my opinion it's more useful on smaller samples of around a few hundred data points.
#
# It is a separate question whether the amount of correlation observed is interesting. Statistical significance just says it's unlikely that this sample came from completely random data. The value of the correlation coefficient says how strongly Y depends on X.

# %%
import scipy

scipy.stats.pearsonr(df['median_house_value'], df['median_income'])
# Out:
# (0.6880752079585478, 0.0)

# %%
scipy.stats.pearsonr(df['total_rooms'], df['total_bedrooms'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-806bd429bce2> in <module>
# ----> 1 scipy.stats.pearsonr(df['total_rooms'], df['total_bedrooms'])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3934     # [-5e210, 5e210, 3e200, -3e200]
#    3935     normxm = linalg.norm(xm)
# -> 3936     normym = linalg.norm(ym)
#    3937
#    3938     threshold = 1e-13
#
# ~\Anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
#     141     else:
#     142         a = np.asarray(a)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     486     a = asarray(a, dtype=dtype, order=order)
#     487     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 488         raise ValueError(
#     489             "array must not contain infs or NaNs")
#     490     return a
#
# ValueError: array must not contain infs or NaNs

# %%
df[df['total_bedrooms'].isna()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
#        population  households  median_income  median_house_value  \
# 290         570.0       218.0         4.3750            161900.0
# 341         732.0       259.0         1.6196             85100.0
# 538        3741.0      1273.0         2.5762            173400.0
# 563         384.0       146.0         4.9489            247100.0
# 696         387.0       161.0         3.9063            178400.0
# ...           ...         ...            ...                 ...
# 20267      3171.0       779.0         3.3409            220500.0
# 20268      1938.0       762.0         1.6953            167400.0
# 20372      1701.0       669.0         5.1033            410700.0
# 20460      2734.0       814.0         6.6073            258100.0
# 20484      1705.0       495.0         5.7376            218600.0
#
#       ocean_proximity
# 290          NEAR BAY
# 341          NEAR BAY
# 538          NEAR BAY
# 563          NEAR BAY
# 696          NEAR BAY
# ...               ...
# 20267      NEAR OCEAN
# 20268      NEAR OCEAN
# 20372       <1H OCEAN
# 20460       <1H OCEAN
# 20484       <1H OCEAN
#
# [207 rows x 10 columns]

# %%
df_no_nan = df.dropna()   # or use df.dropna(inplace = True)

# %%
scipy.stats.pearsonr(df_no_nan['total_rooms'], df_no_nan['total_bedrooms'])
# Out:
# (0.9303795046865079, 0.0)

# %%
scipy.stats.pearsonr(df_no_nan['housing_median_age'], df_no_nan['latitude'])
# Out:
# (0.011899066824498292, 0.08896986250900428)

# %%
scipy.stats.pearsonr(df_no_nan['longitude'], df_no_nan['latitude'])
# Out:
# (-0.9246161131160109, 0.0)

# %% [markdown]
# ### Incuding non-numeric values in correlation

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
for i, row in df.iterrows():
    rank = 0
    if row['ocean_proximity'] == "INLAND":
        rank = 1
    elif row['ocean_proximity'] == "<1H OCEAN":
        rank = 2
    elif row['ocean_proximity'] == "NEAR BAY":
        rank = 3
    elif row['ocean_proximity'] == "NEAR OCEAN":
        rank = 4
    elif row['ocean_proximity'] == "ISLAND":
        rank = 5
    df.loc[i,'ocean_ranking'] = rank

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    ocean_ranking
# 0            3.0
# 1            3.0
# 2            3.0
# 3            3.0
# 4            3.0

# %%
sns.heatmap(df.corr(method='spearman'), cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Don't use pearsons (standard) correlation with non continuous data. Rank correlations (either Spearman's or Kendall's) are able to identify correlation also when the relationship is non linear (but still monotonic). Rank correlation can be used with categories of data that are clearly ordered, pearsons should not be used in this case. Could possibly apply in this case but 5 categories isn't many and also are they really in a clear order? Rank correlations also more robust to outliers. If your data doesn't have inherent order -- as is arguably the case with the ocean proximity -- you cannot use correlation statistics to understand it!! If you assign numbers to the categories then the correlations can be calculated but they will be meaningless. Please don't do this!

# %%
df = df.drop('ocean_proximity', axis=1)

# %%
df.head()

# %% [markdown]
# ## Simple visualisation of location vs house value
#
# We can observe a strong correlation between the latitude and longitude in our data. Is that interesting? How can we explain it?
#
# Relationship between location data and some other variable is often best understood visually.

# %%
sns.set_style(style="darkgrid", rc=None)
g = sns.relplot(
    kind='scatter',
    data=df,
    x="longitude", 
    y="latitude",
    hue="median_house_value", 
    size="population",
    palette=plt.get_cmap('jet'), 
    sizes=(10, 100), 
    height=8, 
    aspect=1.5
)

# %% [markdown]
# We can see that the most expensive houses are located near San Francisco (37.7749° N, 122.4194° W) and Los Angeles (34.0522° N, 118.2437°).

# %%
df.plot(
    kind='scatter',
    x='longitude', 
    y='latitude', 
    alpha=0.4, 
    s=df['population'], 
    label='population',
    figsize=(12, 8), 
    c='median_house_value', 
    cmap=plt.get_cmap('jet'), 
    colorbar=True
)
plt.legend()
plt.show()

# %%
df.plot(
    kind='scatter',
    x='longitude', 
    y='latitude', 
    alpha=0.4, 
    s=df['population']/100, 
    label='population',
    figsize=(12, 8), 
    c='median_house_value', 
    cmap=plt.get_cmap('jet'), 
    colorbar=True
)
plt.legend()
plt.show()

# %% [markdown]
# ## Exploring data with lots of scatter plots
#
# Instead of calculating coefficients we can get a quick idea of like correlation between different variables by drawing lots of scatter plots. This kind of visual inspection is often really useful early in an analysis.

# %%
df['density'] = df['population']/df['total_rooms']

# %%
#g = sns.pairplot(df[['median_income', 'median_house_value', 'density']])
g = sns.PairGrid(df[['median_income', 'median_house_value', 'density']])
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
df['density'].max()
# Out:
# 392.63157894736844

# %%
family_size = df['population']/df['households']

# %%
family_size
# Out:
# 0        2.555556
# 1        2.109842
# 2        2.802260
# 3        2.547945
# 4        2.181467
#            ...
# 20635    2.560606
# 20636    3.122807
# 20637    2.325635
# 20638    2.123209
# 20639    2.616981
# Length: 20640, dtype: float64

# %%
df['family_size'] = family_size

# %%
outliers = df[df['density'] > 5]
outliers
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3364     -120.51     40.41                36.0         36.0             8.0
# 4861     -118.28     34.02                29.0        515.0           229.0
# 8874     -118.45     34.06                52.0        204.0            34.0
# 9172     -118.59     34.47                 5.0        538.0            98.0
# 12104    -117.33     33.97                 8.0        152.0            19.0
# 13034    -121.15     38.69                52.0        240.0            44.0
# 13366    -117.63     33.94                36.0        447.0            95.0
# 15790    -122.40     37.77                52.0        144.0            63.0
# 16420    -121.29     37.89                26.0        161.0            27.0
# 16643    -120.65     35.32                20.0        626.0           212.0
# 16669    -120.70     35.32                46.0        118.0            17.0
# 19006    -121.98     38.32                45.0         19.0             5.0
# 19435    -121.04     37.67                16.0         19.0            19.0
# 19524    -121.00     37.64                19.0        121.0            41.0
# 20352    -119.09     34.22                 8.0         40.0            10.0
#
#        population  households  median_income  median_house_value  \
# 3364       4198.0         7.0         5.5179             67500.0
# 4861       2690.0       217.0         0.4999            500001.0
# 8874       1154.0        28.0         9.3370            500001.0
# 9172       8733.0       105.0         4.2391            154600.0
# 12104      1275.0        20.0         1.6250            162500.0
# 13034      6675.0        29.0         6.1359            225000.0
# 13366      2886.0        85.0         4.2578            183300.0
# 15790      1061.0        68.0         4.3958            225000.0
# 16420      1542.0        30.0         5.7485            162500.0
# 16643      3574.0       261.0         1.0298            300000.0
# 16669      6532.0        13.0         4.2639            350000.0
# 19006      7460.0         6.0        10.2264            137500.0
# 19435       166.0         9.0         0.5360            162500.0
# 19524       658.0        41.0         0.9573            162500.0
# 20352       309.0        16.0         4.0208             52500.0
#
#        ocean_ranking     density  family_size
# 3364             1.0  116.611111   599.714286
# 4861             2.0    5.223301    12.396313
# 8874             2.0    5.656863    41.214286
# 9172             1.0   16.232342    83.171429
# 12104            1.0    8.388158    63.750000
# 13034            1.0   27.812500   230.172414
# 13366            1.0    6.456376    33.952941
# 15790            3.0    7.368056    15.602941
# 16420            1.0    9.577640    51.400000
# 16643            4.0    5.709265    13.693487
# 16669            4.0   55.355932   502.461538
# 19006            1.0  392.631579  1243.333333
# 19435            1.0    8.736842    18.444444
# 19524            1.0    5.438017    16.048780
# 20352            4.0    7.725000    19.312500

# %%
Outliers_size = (len(outliers)/len(df))*100
print (Outliers_size)
# Out:
# 0.07267441860465117

# %% [markdown]
# ### Plotting a regression line
#
# If the two data series seem like they are related and the relationship can be described by a straight line then we can plot a best fit line using linear regression.

# %%
sns.regplot(
    data=df, 
    x='median_income', 
    y='median_house_value', 
    scatter_kws={"color": "orange"}
)
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>

# %%
df[df['median_house_value'] > 500000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 89       -122.27     37.80                52.0        249.0            78.0
# 459      -122.25     37.87                52.0        609.0           236.0
# 493      -122.24     37.86                52.0       1668.0           225.0
# 494      -122.24     37.85                52.0       3726.0           474.0
# 509      -122.23     37.83                52.0       2990.0           379.0
# ...          ...       ...                 ...          ...             ...
# 20422    -118.90     34.14                35.0       1503.0           263.0
# 20426    -118.69     34.18                11.0       1177.0           138.0
# 20427    -118.80     34.19                 4.0      15572.0          2222.0
# 20436    -118.69     34.21                10.0       3663.0           409.0
# 20443    -118.85     34.27                50.0        187.0            33.0
#
#        population  households  median_income  median_house_value  \
# 89          396.0        85.0         1.2434            500001.0
# 459        1349.0       250.0         1.1696            500001.0
# 493         517.0       214.0         7.8521            500001.0
# 494        1366.0       496.0         9.3959            500001.0
# 509         947.0       361.0         7.8772            500001.0
# ...           ...         ...            ...                 ...
# 20422       576.0       216.0         5.1457            500001.0
# 20426       415.0       119.0        10.0472            500001.0
# 20427      5495.0      2152.0         8.6499            500001.0
# 20436      1179.0       371.0        12.5420            500001.0
# 20443       130.0        35.0         3.3438            500001.0
#
#        ocean_ranking   density  family_size
# 89               3.0  1.590361     4.658824
# 459              3.0  2.215107     5.396000
# 493              3.0  0.309952     2.415888
# 494              3.0  0.366613     2.754032
# 509              3.0  0.316722     2.623269
# ...              ...       ...          ...
# 20422            2.0  0.383234     2.666667
# 20426            2.0  0.352591     3.487395
# 20427            2.0  0.352877     2.553439
# 20436            2.0  0.321867     3.177898
# 20443            2.0  0.695187     3.714286
#
# [965 rows x 12 columns]

# %% [markdown]
# We could check whether the practice of not recording values over half a million has affected the best fit line by excluding these data points.

# %%
sns.regplot(
    data=df[df['median_house_value'] < 500000], 
    x='median_income', 
    y='median_house_value', 
    scatter_kws={"color": "orange"}
)
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>

# %%
sns.regplot(
    data=df, 
    x='total_rooms', 
    y='total_bedrooms', 
    scatter_kws={"color": "orange"}
)
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='total_bedrooms'>

# %% [markdown]
# ## Linear vs logistic regression
#
# The iris dataset has measurements of different flowers together with labels indicating the species of iris flower the measurements came from. We will look for a relationship between the measurements and species.

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# To begin with we'll simplify by just looking at two of the species.

# %%
iris_2 = iris[iris['species']!='virginica']

# %% [markdown]
# We want to use linear regression to draw a line that summarises the relationship, as we did before.

# %%
sns.regplot(data=iris_2, x='petal_length', y='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(data=iris_2, x='petal_length', y='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.regplot(data=iris_2, x='petal_length', y='species')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-641f5d8eab8b> in <module>
# ----> 1 sns.regplot(data=iris_2, x='petal_length', y='species')
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 838     plotter.plot(ax, scatter_kws, line_kws)
#     839     return ax
#     840
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     368
#     369         if self.fit_reg:
# --> 370             self.lineplot(ax, line_kws)
#     371
#     372         # Label the axes
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     411         """Draw the model."""
#     412         # Fit the regression model
# --> 413         grid, yhat, err_bands = self.fit_regression(ax)
#     414         edges = grid[0], grid[-1]
#     415
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     219             yhat, yhat_boots = self.fit_logx(grid)
#     220         else:
# --> 221             yhat, yhat_boots = self.fit_fast(grid)
#     222
#     223         # Compute the confidence interval at each grid point
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in fit_fast(self, grid)
#     236         X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#     237         grid = np.c_[np.ones(len(grid)), grid]
# --> 238         yhat = grid.dot(reg_func(X, y))
#     239         if self.ci is None:
#     240             return yhat, None
#
# ~\Anaconda3\lib\site-packages\seaborn\regression.py in reg_func(_x, _y)
#     232         """Low-level regression and prediction using linear algebra."""
#     233         def reg_func(_x, _y):
# --> 234             return np.linalg.pinv(_x).dot(_y)
#     235
#     236         X, y = np.c_[np.ones(len(self.x)), self.x], self.y
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# It can't fit a regression line because one of the data types is not numeric. Let's fix that.

# %%
for i, row in iris.iterrows():
    if row.species == 'versicolor':
        iris.loc[i, 's'] = 1
    else:
        iris.loc[i, 's'] = 0

# %%
iris

# %%
iris_2 = iris[iris['species']!='virginica']

# %% [markdown]
# Now we've represented the species as a number we can draw a regression line. But is this the best way to explain the relationship between petal length and species?

# %%
sns.regplot(data=iris_2, x='petal_length', y='s')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='s'>

# %% [markdown]
# Usually with a regression line we want to use it where one value is known and we look at the line to estimate the other value. So here we could say if a petal length of 3 is observed, the value for the species is expected to be around 0.55. What does 0.55 mean? Not really anything, because the species value isn't continuous. We can't have a flower which is halfway between the two. Instead, we want to know how likely is it that a petal length of 3 means we have a setosa or versicolor flower. This is better achieved with logistic regression, which is a method for classification.

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X = np.array(iris_2['petal_length']).reshape(-1, 1)
y = iris_2['species']
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# We've split the data into a train and test set to be able to check how good the classification is. Scikitlearn provides a method to calculate the logistic regression model from the paired training data, which we've done. Now we can use the model to make predictions on the remaining data. Given a measurement of petal length, which species should we say that this is?

# %%
prediction = logreg.predict(X_test)

# %%
X_test.shape
# Out:
# (50, 1)

# %%
prediction
# Out:
# array(['setosa', 'versicolor', 'versicolor', 'versicolor', 'setosa',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'setosa', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'setosa', 'versicolor', 'setosa',
#        'setosa', 'versicolor', 'setosa', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'setosa', 'versicolor'],
#       dtype=object)

# %%
plt.scatter(X_test, prediction)

# %% [markdown]
# The plot shows the predictions that the model made on the testing data. Now we can check if it was correct.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        31
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# This was a really simple example and we could perfectly classify the test set! We can use more inputs to see how the model classifies flowers based on the different peral lengths.

# %%
x_values = np.linspace(1,5,500)
x_values.shape
# Out:
# (500,)

# %%
x_values = x_values.reshape(-1, 1)

# %%
x_values.shape
# Out:
# (500, 1)

# %%
prediction = logreg.predict(x_values)

# %%
prediction.shape
# Out:
# (500,)

# %%
plt.scatter(x_values, prediction)

# %% [markdown]
# Behind the classification decision there is a value for each possible input specifying the probability that the model assigns to that value belonging to the setosa or versicolor species. We can also plot this out.

# %%
predict_probs = logreg.predict_proba(x_values)[:,1]

# %%
plt.scatter(x_values, y = predict_probs)

# %% [markdown]
# Logistic regression is simplest to understand in the 2 class case, but it can also be used for more classes. For each class it calculates a probability of a measurement indicating membership of that class. In combination, these probabilities allow the model to make a prediction.

# %%
iris = sns.load_dataset("iris")
X = np.array(iris['petal_length']).reshape(-1, 1)
y = iris['species']
X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.5)

# %%
model = LogisticRegression().fit(X_train, y_train)

# %%
print(model.predict(X_test))
# Out:
# ['versicolor' 'versicolor' 'setosa' 'setosa' 'setosa' 'virginica'
#  'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica' 'virginica'
#  'virginica' 'setosa' 'versicolor' 'virginica' 'virginica' 'versicolor'
#  'setosa' 'versicolor' 'versicolor' 'versicolor' 'versicolor' 'virginica'
#  'versicolor' 'versicolor' 'versicolor' 'setosa' 'versicolor' 'versicolor'
#  'setosa' 'setosa' 'virginica' 'virginica' 'versicolor' 'virginica'
#  'virginica' 'setosa' 'virginica' 'setosa' 'virginica' 'versicolor'
#  'setosa' 'virginica' 'versicolor' 'virginica' 'versicolor' 'virginica'
#  'virginica' 'virginica' 'virginica' 'setosa' 'setosa' 'virginica'
#  'virginica' 'versicolor' 'setosa' 'versicolor' 'virginica' 'setosa'
#  'setosa' 'setosa' 'virginica' 'setosa' 'versicolor' 'versicolor'
#  'versicolor' 'virginica' 'setosa' 'setosa' 'virginica' 'virginica'
#  'versicolor' 'setosa' 'versicolor']

# %%
pred_correct = model.predict(X_test) == y_test

# %%
pred_correct.sum()
# Out:
# 71

# %%
pred_correct.shape
# Out:
# (75,)

# %% [markdown]
# Again, we can plot the probabilities assigned to each measurement that it comes from each species.

# %%
x_values = np.linspace(1,5,500)

# %%
predict_probs = model.predict_proba(x_values.reshape(-1,1))

# %%
predict_probs
# Out:
# array([[9.84468737e-01, 1.55310806e-02, 1.81988611e-07],
#        [9.84173425e-01, 1.58263849e-02, 1.89757989e-07],
#        [9.83872590e-01, 1.61272120e-02, 1.97857925e-07],
#        ...,
#        [2.27051809e-03, 4.83465827e-01, 5.14263654e-01],
#        [2.20127490e-03, 4.77777223e-01, 5.20021502e-01],
#        [2.13385850e-03, 4.72092523e-01, 5.25773619e-01]])

# %%
model.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# probability of setosa
plt.scatter(x_values, predict_probs[:,0])

# %%
# probability of versicolor
plt.scatter(x_values, predict_probs[:,1])

# %%
# probability of virginica
plt.scatter(x_values, predict_probs[:,2])
